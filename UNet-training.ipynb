# %%
import torch
from model import UNet
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## result on untrained model

# %%
model = UNet(in_channels=1, out_channels=1) # model instantiation
img = Image.open("data/dataset/train/y/0a0ab305-1fd0-46e8-9828-f8efe28b15c2.png")
imarr = np.array(img, dtype="float64")
imarr /= np.array([65535], dtype=np.float64)
# imtensor = torch.tensor([imarr], dtype=torch.double)
# imtensor = torch.ones((1, 572, 572), dtype=torch.double)
model_output = model.forward(torch.DoubleTensor([imarr]))
model_output.size()
data = model_output.detach().numpy()
plt.imshow(data[0, :, :])
# Out:
# /var/folders/q9/gr1yp8lj3bd65hlwr2q9q5tr0000gn/T/ipykernel_71956/3250963553.py:7: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  /Users/runner/miniforge3/conda-bld/pytorch-recipe_1647804309932/work/torch/csrc/utils/tensor_new.cpp:210.)
#   model_output = model.forward(torch.DoubleTensor([imarr]))
