# %%
import torch
import numpy as np
from PIL import Image
from torchvision import transforms
import copy

# %%
# Running test.py
# !python3 Uformer/test.py --arch Uformer --batch_size 1 --input_dir tests --result_dir tests/output --weights ./pretrained_models/uformer16_denoising_sidd_cpu.pth --embed_dim 16
# Out:
# You choose Uformer...
# ===>Testing using weights:  ./pretrained_models/uformer16_denoising_sidd_cpu.pth
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "Uformer/test.py", line 87, in <module>
#     psnr_val_rgb = sum(psnr_val_rgb)/len(test_dataset)
# ZeroDivisionError: division by zero

# %%
inp = Image.open("tests/input/CDStent_noise4.png")
gt = Image.open("tests/groundtruth/CDStent.png")
out = Image.open("tests/output/CDStent.png")

display(inp.resize((200, 200)))
display(gt.resize((200, 200)))
display(out.resize((200, 200)))
# Out:
# <PIL.Image.Image image mode=I size=200x200 at 0x7FEBB712BF70>
# <PIL.Image.Image image mode=I size=200x200 at 0x7FEBB71A8C40>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FEBB70DC610>
